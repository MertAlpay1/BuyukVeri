# %%
# Out:
# CONTAINER ID   IMAGE                                  COMMAND                  CREATED         STATUS                   PORTS                                                                                      NAMES
# e0077a2e89b0   bd-producer                            "python producer.py"     2 minutes ago   Up 2 minutes                                                                                                        producer
# 850587d1a2a6   apache/spark:3.5.1                     "/opt/entrypoint.sh â€¦"   2 minutes ago   Up 2 minutes                                                                                                        spark-worker
# 2b6c669c6eb5   jupyter/pyspark-notebook:spark-3.5.0   "tini -g -- start-noâ€¦"   2 minutes ago   Up 2 minutes (healthy)   0.0.0.0:8888->8888/tcp, [::]:8888->8888/tcp                                                jupyter
# ...

# %%
# Out:
# Mevcut topicler: ['world_energy_consumption']

# %% [markdown]
# Buraya ekran görüntüsü gelecek docker desktop
